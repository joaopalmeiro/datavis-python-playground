# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from charts import stellar_chart

# %% [markdown]
# # Data

# %%
df_1 = pd.DataFrame(
    {
        "group": ["A", "B", "C", "D"],
        "var1": [38, 1.5, 30, 4],
        "var2": [29, 10, 9, 34],
        "var3": [8, 39, 23, 24],
        "var4": [7, 31, 33, 14],
        "var5": [28, 15, 32, 14],
    }
)

df_2 = pd.DataFrame(
    {
        "group": ["A"],
        "stamina": [70],
        "python-skill": [100],
        "strength": [80],
        "break-dance": [66],
        "speed": [45],
        "health": [72],
        "healing": [90],
        "energy": [12],
        "libido": [100],
    }
)

# %% [markdown]
# # Stellar chart

# %%
stellar_chart(df_1, "group", 40)

# %%
stellar_chart(df_2, "group", 100)

# %% [markdown]
# ---
