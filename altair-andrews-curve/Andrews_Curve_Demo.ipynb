# %% [markdown]
# # Andrews Curve
#
# A possible [Altair](https://altair-viz.github.io/) implementation of an [Andrews curve](https://en.wikipedia.org/wiki/Andrews_plot). Data preparation for this chart is done with the help of [NumPy](https://numpy.org/) and [pandas](https://pandas.pydata.org/). This implementation is based on that available in [PdVega](https://altair-viz.github.io/pdvega/) (created by Jake VanderPlas), as well as the theoretical definition available on the respective [Wikipedia page](https://en.wikipedia.org/wiki/Andrews_plot).

# %%
# %load_ext autoreload
# %autoreload 2

from vega_datasets import data
import altair as alt
import numpy as np
import pandas as pd

from configs import set_pd_options, set_alt_aesthetic
from data import get_andrews_curve_dataset
from charts import andrews_curve

set_pd_options()
set_alt_aesthetic(disable_max_rows=True)
# Out:
#             <style>
#                 #vg-tooltip-element.vg-tooltip.lcontrast-theme {
#                     color: #44475A;
#                     border: 1px solid #EBEBEB;
#                     font-family: Roboto;
#                     font-size: 11px;
#                 }
#                 #vg-tooltip-element.vg-tooltip.lcontrast-theme td.key {
#                     color: #44475A;
#                     font-weight: bold;
#                 }
#             </style>

# %%
iris = data.iris()
iris.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
andrews = get_andrews_curve_dataset(iris, "species")
andrews.head()
# Out:
#         t  sample  curve_value  target
# 0 -3.1416       0       2.2062  setosa
# 1 -3.1100       0       2.1091  setosa
# 2 -3.0784       0       2.0134  setosa
# 3 -3.0469       0       1.9192  setosa
# 4 -3.0153       0       1.8265  setosa

# %%
help(andrews_curve)
# Out:
# Help on function andrews_curve in module charts:
#
# andrews_curve(data: pandas.core.frame.DataFrame, xvar: str = 't', yvar: str = 'curve_value', targetvar: str = 'target', samplevar: str = 'sample', w: int = 450, h: int = 300) -> altair.vegalite.v4.api.LayerChart

# %%
andrews_curve(andrews)
# Out:
# alt.LayerChart(...)
